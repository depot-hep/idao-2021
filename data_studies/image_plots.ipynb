# %%
from utils import *

# %%
rand_seed = 42
crop_size = (200, 200)
max_num_images = 5

# %% [markdown]
# # ER, 1 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/ER', class_to_plot='ER', energy_to_plot=1, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 1 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/NR', class_to_plot='NR', energy_to_plot=1, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 3 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/ER', class_to_plot='ER', energy_to_plot=3, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 3 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/NR', class_to_plot='NR', energy_to_plot=3, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 6 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/ER', class_to_plot='ER', energy_to_plot=6, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 6 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/NR', class_to_plot='NR', energy_to_plot=6, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 10 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/ER', class_to_plot='ER', energy_to_plot=10, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 10 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/NR', class_to_plot='NR', energy_to_plot=10, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 20 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/ER', class_to_plot='ER', energy_to_plot=20, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 20 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/NR', class_to_plot='NR', energy_to_plot=20, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 30 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/ER', class_to_plot='ER', energy_to_plot=30, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 30 keV

# %%
plotted_ims = plot_images('../../idao_dataset/train/NR', class_to_plot='NR', energy_to_plot=30, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)
