# %%
from utils import *

# %%
rand_seed = 42
crop_size = (200, 200)
max_num_images = 5

# %%
## plot some random images from public test, private test and train

images_to_plot = ['0db596814179456485b6e076cdf789c293335892.png', '0f2298795361a85381c1d53a98458803fedb41d0.png', '1e08f1e9a8c611a99034900d7e71254f3e0bb0e9.png',
                  '1ee937270de2993da43506e0c8615bfae80d294f.png', '1ff57d8ff8ddac3858253e1ec0624d34d52eb528.png',
                 '1504596af6b3281df29ae27573cb74640e189f91.png', '1742062bc8fadbcc2ed6c8d291aefb4dcdb98f63.png', '1851331d12f186e64ede2597d087272c10a63884.png',
                 '4127548f8ef8519c3264ef72ad55ffe8549872f7.png', '5018088efff3be1721bda3723a0a424aa85f7b41.png',
                 '-0.9262655377388__CYGNO_60_40_ER_30_keV_930V_30cm_IDAO_iso_crop_hist_pic_run3_ev623;1.png', '-0.310972660779953__CYGNO_60_40_ER_30_keV_930V_30cm_IDAO_iso_crop_hist_pic_run2_ev468;1.png',
                 '-0.578673243522644__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run1_ev482;1.png', '-0.625__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev537;1.png',
                  '-0.066600002348423__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev251;1.png']
plotted_ims = plot_images('../../idao_dataset/', im_filename=images_to_plot, crop_images=True, crop_size=crop_size, max_num_images=15, rand_seed=None)

# %%
## plot images from a txt file
plotted_ims = plot_images('../../idao_dataset/', im_filename='images_to_be_plotted.txt', crop_images=True, crop_size=crop_size, max_num_images=15, rand_seed=None)

# %%
## plot images from a csv file
plotted_ims = plot_images('../../idao_dataset/', im_filename='submissions/DT_50_reg_RFT_100_cl.csv', crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)
# Out:
# 56100d0c1d652d55836ae357566da0c37ca98b03  not found
# f5917a91926a95dbd9470cd95cc6314d675a5b4d  not found
# 62c211c405fe4220ae21732508c15339f1f4f7e3  not found
# 19aa473268b5ab30b2ebfb14e7304b182f976f7c  not found

# %% [markdown]
# # ER, 1 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='ER', energy_to_plot=1, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 1 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='NR', energy_to_plot=1, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 3 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='ER', energy_to_plot=3, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 3 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='NR', energy_to_plot=3, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 6 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='ER', energy_to_plot=6, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 6 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='NR', energy_to_plot=6, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 10 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='ER', energy_to_plot=10, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 10 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='NR', energy_to_plot=10, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 20 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='ER', energy_to_plot=20, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 20 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='NR', energy_to_plot=20, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # ER, 30 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='ER', energy_to_plot=30, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)

# %% [markdown]
# # NR, 30 keV

# %%
plotted_ims = plot_images('../../idao_dataset/', class_to_plot='NR', energy_to_plot=30, crop_images=True, crop_size=crop_size, max_num_images=max_num_images, rand_seed=rand_seed)
